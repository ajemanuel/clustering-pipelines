# %% [markdown]
# ## Before running, you must:
# 1. Install Ubuntu VirtualBox (my installation is Ubuntu 16.04 LTS) https://www.lifewire.com/run-ubuntu-within-windows-virtualbox-2202098
#     I would dedicate at least 200 GB of hard drive space to this virtualbox.
# 2. Follow mountainsort instructions for installation on your Ubuntu VirtualBox https://github.com/magland/mountainlab
#
#     a. set up your pipeline settings (I copied mine from ms2 and changed some of the parameters to match my default recording configuration)
#
#     b. set up your probe files (you can make a csv file from the geometry specified in the kwik prb file). The first column would be inverted y and the second x to make the templates match the expected geometry.
#
#
# 3. Share folder between host and guest (mine is C://Users/Alan/Desktop/UbuntuShare on the host, and /media/sf_UbuntuShare on the guest)
# 4. Install guest additions on guest (may have to do this twice).
#     command in guest terminal: sudo apt-get install virtualbox-guest-additions-iso
# 5. Checkout ms4 branch on host.
# 6. Map the server drive to a drive on your host (mine is mapped to Z:/)
# 7. Change guest name, username and password in code below:
#     (file.write('call %s guestcontrol GUESTNAME run --username USERNAME --password PASSWORD --exe %s -- --text\n' % (pathToVBOXmanage, UbuntuShell)))
# 7. Change paths in first cell below to reflect your data

# %%
## Specify parameters and paths

dataPath = 'Z:/HarveyLab/Tier1/Alan/Data/20171118/p1' ## this code is written to extract a date folder and a penetration folder, if your data is organized differently, you will have to modify
prb = 'poly2' # None # 'poly2' is shorthand for A1x32-poly2-5mm-...etc
UbuntuShareBase = 'C:/Users/Alan/Desktop/UbuntuShare/'
clusteringPath = 'C:/Users/Alan/Documents/Github/clustering-pipelines'
ms4Path = 'C:/Users/Alan/Documents/GitHub/mountainlab/packages/mlpy/mda'

# %%
import os
os.chdir(dataPath)
import sys
sys.path.append(clusteringPath)
import read_rhd as rhd
import numpy as np
import glob
import matplotlib.pyplot as plt
from shutil import copy2
import datetime
import subprocess
# %matplotlib inline
## import tool to read mda files; mlpy is available on the ms4 github branch (https://github.com/magland/mountainlab/tree/ms4)
sys.path.append(ms4Path)
import mdaio

# %%
files = glob.glob('*.rhd')
#for x in files:
#    print(x)
files.sort(key=os.path.getmtime)  ## WARNING: this sorting may be OS sensitive, could use (key=lambda files: files[-10:-4]) instead
print('Sorted Files:')
for x in files:
    print(x)
    
basename = os.path.basename(dataPath) # taking foldername as basename
secondFolder = os.path.basename(os.path.split(dataPath)[0])
print('{0} is basename'.format(basename))
print('{0} files'.format(len(files)))
# Out:
# Sorted Files:
# gridIndent_171118_104826.rhd
# gridIndent_171118_104852.rhd
# gridIndent_171118_104916.rhd
# gridIndent_171118_104941.rhd
# gridIndent_171118_105006.rhd
# gridIndent_171118_105031.rhd
# gridIndent_171118_105056.rhd
# gridIndent_171118_105121.rhd
# gridIndent_171118_105145.rhd
# gridIndent_171118_105210.rhd
# gridIndent_171118_105235.rhd
# gridIndent_171118_105300.rhd
# gridIndent_171118_105325.rhd
# gridIndent_171118_105350.rhd
# gridIndent_171118_105415.rhd
# gridIndent_171118_105440.rhd
# gridIndent_171118_105505.rhd
# gridIndent_171118_105530.rhd
# gridIndent_171118_105554.rhd
# gridIndent_171118_105619.rhd
# gridIndent_171118_105644.rhd
# gridIndent_171118_105709.rhd
# gridIndent_171118_105734.rhd
# gridIndent_171118_105758.rhd
# gridIndent_171118_105823.rhd
# gridIndent_171118_105848.rhd
# gridIndent_171118_105913.rhd
# gridIndent_171118_105937.rhd
# gridIndent_171118_110002.rhd
# gridIndent_171118_110027.rhd
# gridIndent_171118_110052.rhd
# gridIndent_171118_110117.rhd
# gridIndent_171118_110141.rhd
# gridIndent_171118_110206.rhd
# gridIndent_171118_110231.rhd
# gridIndent_171118_110256.rhd
# gridIndent_171118_110321.rhd
# gridIndent_171118_110346.rhd
# gridIndent_171118_110410.rhd
# gridIndent_171118_110435.rhd
# gridIndent_171118_110500.rhd
# gridIndent_171118_110525.rhd
# gridIndent_171118_110550.rhd
# gridIndent_171118_110615.rhd
# gridIndent_171118_110640.rhd
# gridIndent_171118_110705.rhd
# gridIndent_171118_110729.rhd
# gridIndent_171118_110754.rhd
# gridIndent_171118_110819.rhd
# gridIndent_171118_110844.rhd
# gridIndent_171118_110908.rhd
# gridIndent_171118_110933.rhd
# gridIndent_171118_110958.rhd
# gridIndent_171118_111023.rhd
# gridIndent_171118_111048.rhd
# gridIndent_171118_111112.rhd
# gridIndent_171118_111137.rhd
# gridIndent_171118_111202.rhd
# gridIndent_171118_111226.rhd
# gridIndent_171118_111251.rhd
# gridIndent_171118_111316.rhd
# gridIndent_171118_111341.rhd
# gridIndent_171118_111406.rhd
# gridIndent_171118_111430.rhd
# gridIndent_171118_111455.rhd
# gridIndent_171118_111520.rhd
# gridIndent_171118_111545.rhd
# gridIndent_171118_111609.rhd
# gridIndent_171118_111634.rhd
# gridIndent_171118_111659.rhd
# gridIndent_171118_111724.rhd
# gridIndent_171118_111749.rhd
# gridIndent_171118_111814.rhd
# gridIndent_171118_111838.rhd
# gridIndent_171118_111903.rhd
# incSteps_171118_113028.rhd
# incSteps_171118_113049.rhd
# incSteps_171118_113110.rhd
# incSteps_171118_113131.rhd
# incSteps_171118_113152.rhd
# incSteps_171118_113213.rhd
# incSteps_171118_113234.rhd
# incSteps_171118_113255.rhd
# incSteps_171118_113316.rhd
# incSteps_171118_113337.rhd
# opto1_171118_114256.rhd
# opto1_171118_114355.rhd
# opto1_171118_114455.rhd
# opto1_171118_114555.rhd
# opto1_171118_114655.rhd
# opto1_171118_114755.rhd
# opto1_171118_114855.rhd
# opto1_171118_114955.rhd
# opto1_171118_115055.rhd
# opto1_171118_115155.rhd
# opto1_171118_115255.rhd
# opto1_171118_115355.rhd
# opto1_171118_115455.rhd
# opto1_171118_115555.rhd
# opto1_171118_115655.rhd
# opto1_171118_115755.rhd
# opto1_171118_115855.rhd
# opto1_171118_115955.rhd
# opto1_171118_120055.rhd
# opto1_171118_120155.rhd
# opto1_171118_120255.rhd
# opto1_171118_120355.rhd
# opto1_171118_120455.rhd
# opto1_171118_120555.rhd
# opto1_171118_120655.rhd
# opto1_171118_120755.rhd
# opto1_171118_120855.rhd
# opto1_171118_120955.rhd
# opto1_171118_121055.rhd
# opto1_171118_121155.rhd
# opto1_171118_121255.rhd
# opto1_171118_121355.rhd
# opto1_171118_121455.rhd
# opto1_171118_121555.rhd
# opto2_171118_121703.rhd
# opto2_171118_121801.rhd
# opto2_171118_121902.rhd
# opto2_171118_122002.rhd
# opto3_171118_122115.rhd
# opto3_171118_122214.rhd
# opto3_171118_122314.rhd
# opto3_171118_122414.rhd
# opto4_171118_122525.rhd
# opto4_171118_122624.rhd
# opto4_171118_122724.rhd
# opto4_171118_122824.rhd
# opto4_171118_122933.rhd
# opto4_171118_123032.rhd
# opto4_171118_123132.rhd
# opto4_171118_123232.rhd
# p1 is basename
# 135 files

# %%
#batch write .rhd to large raw.mda

numFiles = len(files)

for i, file in enumerate(files):
    print('\n\n\nExtracting file {0} of {1}\n'.format(i+1, numFiles))
    print(file)
    d = rhd.read_rhd(file)
    
    
    if i == 0:
        recordings = d['amplifier_data']
    else:
        recordings = np.concatenate((recordings,d['amplifier_data']),axis=1)
    
    ##save digital input streams as individual files -- different recordings might have different #s of channels
    for digitalChannel in range(d['board_dig_in_data'].shape[0]):
        d['board_dig_in_data'][digitalChannel].tofile(os.path.splitext(file)[0] + 'chan' + str(digitalChannel) + '.di')
    ##save analog input streams as individual files
    for analogChannel in range(d['aux_input_data'].shape[0]):
        d['aux_input_data'][analogChannel].tofile(os.path.splitext(file)[0] + 'chan' + str(analogChannel) + '.ai')


if not os.path.exists(dataPath+'/alldata'):
    os.mkdir(dataPath+'/alldata')
print('\n\nCopying recordings to .mda file')
mdaio.writemda16ui(recordings,dataPath+'/alldata/raw.mda')
print('Finished copying')
del recordings
# Out:
# Extracting file 1 of 135
#
# gridIndent_171118_104826.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.7 seconds
#
#
#
# Extracting file 2 of 135
#
# gridIndent_171118_104852.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.0 seconds
#
#
#
# Extracting file 3 of 135
#
# gridIndent_171118_104916.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.2 seconds
#
#
#
# Extracting file 4 of 135
#
# gridIndent_171118_104941.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.6 seconds
#
#
#
# Extracting file 5 of 135
#
# gridIndent_171118_105006.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 6 of 135
#
# gridIndent_171118_105031.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.9 seconds
#
#
#
# Extracting file 7 of 135
#
# gridIndent_171118_105056.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.0 seconds
#
#
#
# Extracting file 8 of 135
#
# gridIndent_171118_105121.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.3 seconds
#
#
#
# Extracting file 9 of 135
#
# gridIndent_171118_105145.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.8 seconds
#
#
#
# Extracting file 10 of 135
#
# gridIndent_171118_105210.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.8 seconds
#
#
#
# Extracting file 11 of 135
#
# gridIndent_171118_105235.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.0 seconds
#
#
#
# Extracting file 12 of 135
#
# gridIndent_171118_105300.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.6 seconds
#
#
#
# Extracting file 13 of 135
#
# gridIndent_171118_105325.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 14 of 135
#
# gridIndent_171118_105350.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 15 of 135
#
# gridIndent_171118_105415.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.2 seconds
#
#
#
# Extracting file 16 of 135
#
# gridIndent_171118_105440.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 17 of 135
#
# gridIndent_171118_105505.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 18 of 135
#
# gridIndent_171118_105530.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.9 seconds
#
#
#
# Extracting file 19 of 135
#
# gridIndent_171118_105554.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.7 seconds
#
#
#
# Extracting file 20 of 135
#
# gridIndent_171118_105619.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 21 of 135
#
# gridIndent_171118_105644.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.4 seconds
#
#
#
# Extracting file 22 of 135
#
# gridIndent_171118_105709.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.3 seconds
#
#
#
# Extracting file 23 of 135
#
# gridIndent_171118_105734.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 24 of 135
#
# gridIndent_171118_105758.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.0 seconds
#
#
#
# Extracting file 25 of 135
#
# gridIndent_171118_105823.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.0 seconds
#
#
#
# Extracting file 26 of 135
#
# gridIndent_171118_105848.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.0 seconds
#
#
#
# Extracting file 27 of 135
#
# gridIndent_171118_105913.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.1 seconds
#
#
#
# Extracting file 28 of 135
#
# gridIndent_171118_105937.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.6 seconds
#
#
#
# Extracting file 29 of 135
#
# gridIndent_171118_110002.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.8 seconds
#
#
#
# Extracting file 30 of 135
#
# gridIndent_171118_110027.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.1 seconds
#
#
#
# Extracting file 31 of 135
#
# gridIndent_171118_110052.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 32 of 135
#
# gridIndent_171118_110117.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.7 seconds
#
#
#
# Extracting file 33 of 135
#
# gridIndent_171118_110141.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.0 seconds
#
#
#
# Extracting file 34 of 135
#
# gridIndent_171118_110206.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.8 seconds
#
#
#
# Extracting file 35 of 135
#
# gridIndent_171118_110231.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.0 seconds
#
#
#
# Extracting file 36 of 135
#
# gridIndent_171118_110256.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.1 seconds
#
#
#
# Extracting file 37 of 135
#
# gridIndent_171118_110321.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 38 of 135
#
# gridIndent_171118_110346.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.4 seconds
#
#
#
# Extracting file 39 of 135
#
# gridIndent_171118_110410.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 40 of 135
#
# gridIndent_171118_110435.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 6.7 seconds
#
#
#
# Extracting file 41 of 135
#
# gridIndent_171118_110500.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.5 seconds
#
#
#
# Extracting file 42 of 135
#
# gridIndent_171118_110525.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 43 of 135
#
# gridIndent_171118_110550.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 9.0 seconds
#
#
#
# Extracting file 44 of 135
#
# gridIndent_171118_110615.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.4 seconds
#
#
#
# Extracting file 45 of 135
#
# gridIndent_171118_110640.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.6 seconds
#
#
#
# Extracting file 46 of 135
#
# gridIndent_171118_110705.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.6 seconds
#
#
#
# Extracting file 47 of 135
#
# gridIndent_171118_110729.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 48 of 135
#
# gridIndent_171118_110754.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.6 seconds
#
#
#
# Extracting file 49 of 135
#
# gridIndent_171118_110819.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.3 seconds
#
#
#
# Extracting file 50 of 135
#
# gridIndent_171118_110844.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 51 of 135
#
# gridIndent_171118_110908.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 52 of 135
#
# gridIndent_171118_110933.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.6 seconds
#
#
#
# Extracting file 53 of 135
#
# gridIndent_171118_110958.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.3 seconds
#
#
#
# Extracting file 54 of 135
#
# gridIndent_171118_111023.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 55 of 135
#
# gridIndent_171118_111048.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 56 of 135
#
# gridIndent_171118_111112.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 57 of 135
#
# gridIndent_171118_111137.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.3 seconds
#
#
#
# Extracting file 58 of 135
#
# gridIndent_171118_111202.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.7 seconds
#
#
#
# Extracting file 59 of 135
#
# gridIndent_171118_111226.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 60 of 135
#
# gridIndent_171118_111251.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.8 seconds
#
#
#
# Extracting file 61 of 135
#
# gridIndent_171118_111316.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.5 seconds
#
#
#
# Extracting file 62 of 135
#
# gridIndent_171118_111341.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.7 seconds
#
#
#
# Extracting file 63 of 135
#
# gridIndent_171118_111406.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.7 seconds
#
#
#
# Extracting file 64 of 135
#
# gridIndent_171118_111430.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.8 seconds
#
#
#
# Extracting file 65 of 135
#
# gridIndent_171118_111455.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.2 seconds
#
#
#
# Extracting file 66 of 135
#
# gridIndent_171118_111520.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.8 seconds
#
#
#
# Extracting file 67 of 135
#
# gridIndent_171118_111545.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.9 seconds
#
#
#
# Extracting file 68 of 135
#
# gridIndent_171118_111609.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 7.9 seconds
#
#
#
# Extracting file 69 of 135
#
# gridIndent_171118_111634.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 6.9 seconds
#
#
#
# Extracting file 70 of 135
#
# gridIndent_171118_111659.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 21.996 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 8.3 seconds
#
#
#
# Extracting file 71 of 135
#
# gridIndent_171118_111724.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# ...
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.7 seconds
#
#
#
# Extracting file 113 of 135
#
# opto1_171118_120955.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.7 seconds
#
#
#
# Extracting file 114 of 135
#
# opto1_171118_121055.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.8 seconds
#
#
#
# Extracting file 115 of 135
#
# opto1_171118_121155.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.9 seconds
#
#
#
# Extracting file 116 of 135
#
# opto1_171118_121255.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.6 seconds
#
#
#
# Extracting file 117 of 135
#
# opto1_171118_121355.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.4 seconds
#
#
#
# Extracting file 118 of 135
#
# opto1_171118_121455.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.6 seconds
#
#
#
# Extracting file 119 of 135
#
# opto1_171118_121555.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 22.068 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 5.8 seconds
#
#
#
# Extracting file 120 of 135
#
# opto2_171118_121703.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 59.976 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.5 seconds
#
#
#
# Extracting file 121 of 135
#
# opto2_171118_121801.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.7 seconds
#
#
#
# Extracting file 122 of 135
#
# opto2_171118_121902.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 17.6 seconds
#
#
#
# Extracting file 123 of 135
#
# opto2_171118_122002.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 47.160 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 13.9 seconds
#
#
#
# Extracting file 124 of 135
#
# opto3_171118_122115.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 59.976 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 16.6 seconds
#
#
#
# Extracting file 125 of 135
#
# opto3_171118_122214.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 16.7 seconds
#
#
#
# Extracting file 126 of 135
#
# opto3_171118_122314.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 16.7 seconds
#
#
#
# Extracting file 127 of 135
#
# opto3_171118_122414.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 47.196 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 13.2 seconds
#
#
#
# Extracting file 128 of 135
#
# opto4_171118_122525.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 59.976 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 16.4 seconds
#
#
#
# Extracting file 129 of 135
#
# opto4_171118_122624.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 16.4 seconds
#
#
#
# Extracting file 130 of 135
#
# opto4_171118_122724.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 16.4 seconds
#
#
#
# Extracting file 131 of 135
#
# opto4_171118_122824.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 47.160 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 16.6 seconds
#
#
#
# Extracting file 132 of 135
#
# opto4_171118_122933.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 59.976 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 18.7 seconds
#
#
#
# Extracting file 133 of 135
#
# opto4_171118_123032.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.7 seconds
#
#
#
# Extracting file 134 of 135
#
# opto4_171118_123132.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 15.9 seconds
#
#
#
# Extracting file 135 of 135
#
# opto4_171118_123232.rhd
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 1 board digital input channel.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 47.160 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 12.7 seconds
#
#
# Copying recordings to .mda file
# Finished copying

# %% [markdown]
# # copy raw.mda file to UbuntuShare for mountainsort

# %%
## Copy data to Ubuntu share

dt = datetime.datetime.now()
secondFolder = os.path.basename(os.path.split(dataPath)[0])
print('containing folder:',secondFolder)
print('basename:',basename)
#yearMonthDay = dt.strftime('%Y%m%d')  
UbuntuSharePath = UbuntuShareBase+secondFolder+'/'+basename+'/'

if not os.path.exists(UbuntuSharePath):
    os.makedirs(UbuntuSharePath)
copy2(dataPath+'/alldata/raw.mda',UbuntuSharePath) ## copies raw.mda to UbuntuShare folder
# Out:
# containing folder: 20171118
# basename: p1
# 'C:/Users/Alan/Desktop/UbuntuShare/20171118/p1/raw.mda'

# %%
## define functions for writing and running shell script in Ubuntu virtualbox

def writeUbuntuShell(UbuntuSharePath,basename, probe=None, num_channels=32):
    '''
    UbuntuSharePath is path of path that is shared with Ubuntu Virtualbox
    basename is the string of the containing folder
    probe is shorthand for a probe: 'poly2' for A1x32-Poly2-5mm-50s-177-A32
    
    Returns: string of Ubuntu location of shell
    '''
    oldpath = os.getcwd()
    os.chdir(UbuntuSharePath)
    if probe == 'poly2': # if A1x32-Poly2-5mm-50s-177-A32
        copy2('C://Users/Alan/Documents/Github/clustering-pipelines/poly2Geom.csv',UbuntuSharePath)
        num_channels=32
    dt = datetime.datetime.now()
    secondFolder = os.path.basename(os.path.split(dataPath)[0])
    sortDir = '/home/alan/data/sortProjects/'+secondFolder+'/'+basename # every penetration will have its own sortProject
    #sortDirFull = sortDir+'/datasets/'+basename ## make folder for sortProject with folder name as current date and basename as dataset
    #rawMdaLoc = sortDirFull+'/raw.mda'

    #with open('datasets%s.txt' % (secondFolder) ,'w+') as datasetFile:
    #    datasetFile.write(basename+' /datasets/'+basename+'\n')
    
    #with open('pipelines'+secondFolder+'.txt','w+') as pipelineFile:
    #    pipelineFile.write('ms2alan ms2_alan.pipeline') # default mountainsort pipeline file
    
    with open('params%s.json' % (secondFolder) ,'w+') as paramFile:
        if probe == None:
            paramFile.write('{"samplerate":20000,"sign":-1}') # default sample rate is 20 kHz and usually see negative spikes
        elif probe == 'poly2':
            paramFile.write('{"samplerate":20000,"sign":-1,"adjacency_radius":50}')
    with open('tempShell.sh', 'w+', newline='\n') as shellfile: # newline=\n necessary for linux
        shellfile.write('#! /bin/bash -i\n') # including the -i makes the script interative and this allows for use of default PATH on SSH
        shellfile.write('mkdir -p '+sortDir+'\n')
        
        ## convert .dat to .mda, create prv, and copy to datasets
        shellfile.write('cd /media/sf_UbuntuShare/%s/%s\n' % (secondFolder,basename)) #directory of shared folder in Ubuntu Virtualbox
        #shellfile.write('/home/alan/mountainlab/bin/mdaconvert raw.dat raw.mda --dtype=uint16 --input_format=raw_timeseries --num_channels=%d\n' % (num_channels)) # convert .dat to .mda
        shellfile.write('/home/alan/FImountainlab/bin/prv-create raw.mda\n')
        shellfile.write('cp /media/sf_UbuntuShare/%s/%s/raw.mda.prv %s\n' % (secondFolder,basename,sortDir))
        shellfile.write('cp /home/alan/FImountainlab/packages/mountainsort/pipelines/mountainsort3.mlp %s\n' % (sortDir)) # copy pipeline mlp file to sort directory
        
        ## copy params.json file to sortDir
        
        shellfile.write('cp params%s.json %s/params.json\n' % (secondFolder,sortDir))
        
        if probe == 'poly2':
            shellfile.write('cp poly2Geom.csv %s/geom.csv\n' % (sortDir))

        ## copy datasets.txt and pipelines.txt to sortDir
        #shellfile.write('cp datasets%s.txt %s/datasets.txt\n' % (secondFolder,sortDir))
        #shellfile.write('cp pipelines%s.txt %s/pipelines.txt\n' % (secondFolder,sortDir))
        
        ## move to sortDir and run sorting project
        shellfile.write('cd %s\n' % (sortDir))
        shellfile.write('mlp-run %s/mountainsort3.mlp sort --raw=raw.mda.prv --geom=geom.csv --firings_out=firings.mda --_params=params.json\n'%(sortDir))
    os.chdir(oldpath)
    return '/media/sf_UbuntuShare/%s/%s/tempShell.sh' % (secondFolder, basename)

def runUbuntuShell(UbuntuShell):
    '''
    UbuntuShell is str with linux style directory of shell file
        this directory is returned from the writeUbuntuShell function
    For Alan, that is something like /media/sf_UbuntuShare/DATE/DATABASE/shelltorun.sh
    '''
    with open('ubuntuRun.bat','w+') as file:
        ## change directory to that with share folder
        pathToVBOXmanage = '"C:/Program Files/Oracle/VirtualBox/VBoxManage.exe"'
        file.write('title run ubuntu shell\n')
        
        #####
        ## I've commented out the following bit of code because I set my vbox to always start upon login to Windows
        ## see https://hellojason.net/blog/automatically-launch-a-headless-virtualbox-vm-at-bootup/
        ## You can uncomment to auto startup your virtualbox with this script
        ####
        
        ## start virtual box
        #file.write('call %s startvm "Ubuntu"\n' %(pathToVBOXmanage))
        ## i set up the virtualbox to set the RDONLYHOST property on startup
        ## this wait command waits for that property to change before proceeding
        #file.write('call %s guestproperty wait "Ubuntu" RDONLYHOST\n' %(pathToVBOXmanage))
        
        
        ## executes the script UbuntuShell
        # change username and password to reflect your virtualbox login
        file.write('call %s guestcontrol "Ubuntu" run --username alan --password 123ubuntubox --exe %s -- --text\n' % (pathToVBOXmanage, UbuntuShell))
        
    p = subprocess.Popen('ubuntuRun.bat',shell=True) #run the BAT file.
    stdout, stderr = p.communicate()
    # in jupyter, the stdout appears in the cmd window rather than the browser
    return stdout, stderr

# %%
UbuntuSharePath = UbuntuShareBase+secondFolder+'/'+basename+'/'
ubuntuLocation = writeUbuntuShell(UbuntuSharePath,basename,probe=prb)

# %%
stdout, stderr = runUbuntuShell(ubuntuLocation)
